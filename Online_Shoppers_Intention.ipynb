# %% [markdown]
# <a href="https://colab.research.google.com/github/NewAspects/Notestothe/blob/master/Online_Shoppers_Intention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="background-color:orange;text-align:center;vertical-align:middle"><table><tr><td><pre>
# <!-- <center><h1><font color='darkorange'>Kodluyoruz Academy</font></h1></center> -->
# <p align="center"><img src="https://drive.google.com/uc?id=1XaFRw2Ga--G2TEtlXTau1iuVH0YDTbzC" width=100></p>
# <!--https://www.kodluyoruz.org/wp-content/uploads/2018/02/kodluyoruz_logo_sosyalgirisim.png-->
# <p align="center"><img src="https://drive.google.com/uc?id=1KwcDmzeT0IzJKo_p-opUtwQu75tXbnt7" width=500></p>
# <!--https://www.kodluyoruz.org/wp-content/uploads/2018/03/Frame.png-->
# <center><h1><em><font color='darkorange'>Bootcamp - Applied Data Science</font></em></h1></center>
# <center><h2><em><font color='darkorange'>February-2020</font></em></h2></center>
# <table style="width:35%">
#     <tr>
#         <td><b>Project:</b></td>
#         <td>Online Shoppers Intention </td>
#     </tr>
#     <tr>
#         <td><b>Module-1:</b></td>
#         <td>Supervised Learning</td>
#     </tr>
#     <tr>
#         <td><b>Session-1:</b></td>
#         <td>Binary Classification</td>
#     </tr>
#     <tr>
#         <td><b>Case:</b></td>
#         <td>Probability of Shopping (Revenue=1)</td>
#     </tr>
#     <tr>
#         <td><b>Group Members:</b></td>
#         <td>Mert Sülük</td>
#   </tr>
#   <tr>
#         <td></td>
#         <td>Ayşe Sena Modanlıoğlu</td>
#   </tr>
#     <tr>
#         <td></td>
#         <td>Tunç Aslan</td>
#   </tr>
# </table>
# </pre></td></tr></table></div>

# %% [markdown]
# # Proje Hakkında

# %% [markdown]
# Projemiz, Kaggle'da bulunan **Online Shopper's Intention** veri seti üzerinden geliştirilmiştir. Veri seti, e-ticaret sitesinden toplanmıştır.  Veri setinin hedef sütunu "Revenue"dur. Bu sütunun amacı satış yapılıp yapılmadığını belirtmektir. Hedef sütununun dağılımı ***%84.32'e %15.68'dir.*** Projemizin amacı, belirli şartlara göre satış yapılıp yapılmadığını tahmin etmektir.

# %% [markdown]
# ![picture](https://drive.google.com/uc?id=13c9U7vC235e39eHcWjcBW7-XtP7skYJ7)

# %% [markdown]
# Veri seri üzerinde beş tane modeli iki farklı şekilde, hyperparameter tunning yaparak ve hyperparameter tunning yapmadan denedik.

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1raNtWtMhI0aQaFlAykd2gwcLv7RZSYUu">

# %% [markdown]
# Tune edilmiş ve tune edilmemiş modellerin karşılaştırılması:

# %% [markdown]
# <img src="https://drive.google.com/uc?id=11xOxKOFCv5Fi54a-JtTjrPthEEiqDjJ1" width="6000">

# %% [markdown]
# # Sütun Tipleri

# %% [markdown]
# ***Administrative / Administrative_Duration /
# Informational / Informational_Duration /
# ProductRelated / ProductRelated_Duration:*** Ziyaretçinin o oturumda ziyaret ettiği farklı sayfa türlerinin sayısını ve bu sayfa kategorilerinin her birinde harcanan toplam süreyi temsil eder. Bu veriler, kullanıcı tarafından ziyeret edilen sayfaların URL bilgilerinden türetilmiştir ve kullanıcı bir işlem gerçekleştirdiğinde gerçek zamanlı olarak güncellenmiştir. </br>
#
# ***Bounce_Rate:*** Oturum sırasında siteye o sayfadan giren ve ardından analiz sunucusundan başka istekleri tetiklemeden hemen ayrılan ziyaretçilerin yüzdesini belirtir. Google Analytics ile toplanmıştır. </br>
#
# ***Exit Rate:*** The value of "Exit Rate" feature for a specific web page is calculated as for all pageviews to the page, the percentage that were the last in the session. Google Analytics ile toplanmıştır.</br>
#
# ***Page Value:*** Kullanıcının işlemini tamamlamadan önce web sayfasını ortalama kaç kez ziyaret ettiğini temsil eder.
#
# ***Special_Day:*** İşlem yapılan tarihin, özel bir güne (örneğin sevgililer günü) olan uzaklığını temsil eder.
#
# ***OperatingSystems:*** Ziyaretçinin kullandığı işletim sistemini temsil eder.
#
# ***Browser:*** Ziyaretçinin kullandığı tarayıcıyı temsil eder.
#
# ***Region:*** Kullanıcının hangi bölgeden olduğunu temsil eder.
#
# ***Traffic Type:*** Sayfanın ziyaret edildiği gündeki trafik tipini temsil eder.
#
# ***Visitor Type:*** Kullanıcının yeni kullanıcı mı yoksa eski kullanıcı mı olduğunu temsil eder.
#
# ***Weekend:*** Sayfanın hafta sonu mu yoksa hafta içi mi ziyaret edildiği bilgisini içerir. Boolean'dır.
#
# ***Month:*** Yılın hangi ayında işlem yapıldığı bilgisini içerir.

# %% [markdown]
# # Gerekli Kütüphanelerin Import Edilmesi

# %%
# !pip install category_encoders

# %%
import numpy as np
import pandas as pd
import io
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
import category_encoders as ce

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
import csv
from sklearn import preprocessing

# %% [markdown]
# # Veri Setinin İncelenmesi
# ## Veri Setinin Import Edilmesi

# %%
url="https://drive.google.com/uc?id=1xxMjNxB86m1rQrmMDvKw2PYx_ZHtc9sw"
data=pd.read_csv(url)
data.head()
# Out:
#    Administrative  Administrative_Duration  ...  Weekend  Revenue
# 0             0.0                      0.0  ...    False    False
# 1             0.0                      0.0  ...    False    False
# 2             0.0                     -1.0  ...    False    False
# 3             0.0                      0.0  ...    False    False
# 4             0.0                      0.0  ...     True    False
#
# [5 rows x 18 columns]

# %% [markdown]
# ## Duplicate Verilerin Silinmesi

# %%
data = data.drop_duplicates()
print(data.shape)
# Out:
# (12211, 18)

# %% [markdown]
# ## Sütunların İncelenmesi

# %%
###1##
def MissingUniqueStatistics(df):
  import io
  import pandas as pd
  import psutil, os, gc, time
  proc=psutil.Process(os.getpid())
  gc.collect()
  mem_0=proc.memory_info().rss
  start_time=time.time()

  totalEntryList=[]
  totalMissingValueList=[]
  missingValRateList=[]
  dataTypeList = []
  uniqueValuesList = []
  totalUniqueValList = []
  variableNameList = []
  


  for element in df.columns:

    missingValRate=round((df[element].isna().sum()/len(df[element]))*100,2)
    totalEntryList.append(len(df[element]))
    totalMissingValueList.append(df[element].isna().sum())
    missingValRateList.append(missingValRate)
    dataTypeList.append(list(df[element].unique()))
    uniqueValuesList.append(list(df[element].unique()))
    totalUniqueValList.append(len(df[element].unique()))
    variableNameList.append(element)

    
  data_analysis_df = pd.DataFrame({'Variable': variableNameList,'#_Total_Entry':totalEntryList,\
                                  '#_Missing_Value': totalMissingValueList,'%_Missing_Value':missingValRateList,\
                                  'Data_Type': dataTypeList, 'Unique_Values': uniqueValuesList,\
                                  '#_Unique_Values':totalUniqueValList})
    
  print('MissingUniqueStatistics process has been completed!')
  print("--- in %s minutes ---" % ((time.time() - start_time)/60))
  
  return data_analysis_df.sort_values(by='%_Missing_Value', ascending=False)

# %%
data_analysis = MissingUniqueStatistics(data)
# Out:
# MissingUniqueStatistics process has been completed!
# --- in 0.0005213459332784017 minutes ---

# %%
data_analysis
# Out:
#                    Variable  ...  #_Unique_Values
# 0            Administrative  ...               28
# 2             Informational  ...               18
# 3    Informational_Duration  ...             1260
# 4            ProductRelated  ...              312
# 5   ProductRelated_Duration  ...             9553
# 6               BounceRates  ...             1873
# 7                 ExitRates  ...             4778
# 1   Administrative_Duration  ...             3337
# 13                   Region  ...                9
# 16                  Weekend  ...                2
# 15              VisitorType  ...                3
# 14              TrafficType  ...               20
# 9                SpecialDay  ...                6
# 12                  Browser  ...               13
# 11         OperatingSystems  ...                8
# 10                    Month  ...               10
# 8                PageValues  ...             2704
# 17                  Revenue  ...                2
#
# ...

# %% [markdown]
# ### Sütun veri tiplerinin belirlenmesi

# %%
types = ["Cardinal","Cardinal","Continuous",
         "Cardinal","Continuous", "Continuous",
         "Continuous","Continuous", "Nominal",
         "Nominal","Nominal","Nominal", 
         "Ordinal", "Nominal", "Nominal",
         "Ordinal", "Continuous", "Nominal"]


data_analysis["Variables"] = types

# %%
data_analysis
#Veri tipleriyle beraber
# Out:
#                    Variable  #_Total_Entry  ...  #_Unique_Values   Variables
# 0            Administrative          12211  ...               28    Cardinal
# 2             Informational          12211  ...               18    Cardinal
# 3    Informational_Duration          12211  ...             1260  Continuous
# 4            ProductRelated          12211  ...              312    Cardinal
# 5   ProductRelated_Duration          12211  ...             9553  Continuous
# 6               BounceRates          12211  ...             1873  Continuous
# 7                 ExitRates          12211  ...             4778  Continuous
# 1   Administrative_Duration          12211  ...             3337  Continuous
# 13                   Region          12211  ...                9     Nominal
# 16                  Weekend          12211  ...                2     Nominal
# 15              VisitorType          12211  ...                3     Nominal
# ...

# %% [markdown]
# #### Sayısal ve kategorik sütunların tanımlanması

# %%
numerical_columns =  (data_analysis[(data_analysis["Variables"] == 'Continuous') | (data_analysis["Variables"] == 'Cardinal')]["Variables"])

# %% [markdown]
# ## Eksik Verilerin İncelenmesi

# %%
Zero_MR_variables_list = list(data_analysis[data_analysis['%_Missing_Value']==0].index)
Low_MR_variables_list = list(data_analysis[(data_analysis['%_Missing_Value']>0)&(data_analysis['%_Missing_Value']<=0.05)].index)
Moderate_MR_variables_list = list(data_analysis[(data_analysis['%_Missing_Value']>0.05)&\
                                                      (data_analysis['%_Missing_Value']<=0.25)].index)
High_MR_variables_list = list(data_analysis[(data_analysis['%_Missing_Value']>0.25)&\
                                                  (data_analysis['%_Missing_Value']<=0.50)].index)
Extreme_MR_variables_list = list(data_analysis[(data_analysis['%_Missing_Value']>0.50)&
                                           (data_analysis['%_Missing_Value']<=0.95)].index)
Drop_MR_variables_list = list(data_analysis[data_analysis['%_Missing_Value']>0.95].index)

len(Zero_MR_variables_list),len(Low_MR_variables_list),len(Moderate_MR_variables_list),len(High_MR_variables_list),\
len(Extreme_MR_variables_list),\
len(Zero_MR_variables_list)+len(Low_MR_variables_list)+len(Moderate_MR_variables_list)+len(High_MR_variables_list)+\
len(Extreme_MR_variables_list) == len(data_analysis)-1
# Out:
# (10, 0, 8, 0, 0, False)

# %%
msno.matrix(data,figsize=(10,5))   #Missinglerin nerde olduğu ve rastlantısallığına görsel şekilde bakalım.

# %%
msno.heatmap(data,figsize=(10,5))         #Missing Value'ların bir korelasyon içerisinde olduğunu gördük. Ayrıca bu tüm aynı satırların missing olduğu anlamına gelir.
                                          #Dropping bu yüzden iyi bir yöntem olabilir.

# %% [markdown]
# Eksik veriler az sayıda olduğundan, aynı gözlemlerin çoğu değişkeninde eksiklikler gözlendiğinden ve bu eksiklikler neticesinde bu gözlemlerin bilgi taşımamasından drop etmeyi uygun bulduk.

# %%
data.dropna(inplace=True)

# %% [markdown]
# ### Datamızda değerlerin sayısını görebilmek için value counts değerlerini bir sutun için çağırdık.
# ### Parametre olarak dropna=false vererek nan olan değerlerin de gözükmesini sağladık.

# %%
data["Informational"].value_counts(dropna=False)
# Out:
# 0.0     9569
# 1.0     1041
# 2.0      727
# 3.0      380
# 4.0      222
# 5.0       99
# 6.0       78
# 7.0       36
# 9.0       15
# 8.0       14
# 10.0       7
# 12.0       5
# 14.0       2
# 11.0       1
# 16.0       1
# 24.0       1
# 13.0       1
# Name: Informational, dtype: int64

# %% [markdown]
# ### Yapısal bir bozukluk olduğunu düşündüğümüzden bu aşamada data durationları -1 olan gözlemleri dropladık. (Süre negatif olamaz)

# %%
data=data[(data["Administrative_Duration"]>=0)]

data.shape
# Out:
# (12166, 18)

# %%
data_analysis=data_analysis.set_index("Variable")

# %%
numerical_columns =  list(data_analysis[(data_analysis["Variables"] == 'Continuous') | (data_analysis["Variables"] == 'Cardinal')].index)

# %%
categorical_columns = list(data_analysis.loc[(data_analysis.Variables=="Nominal") | (data_analysis.Variables=="Ordinal")].index)
len(categorical_columns), categorical_columns
# Out:
# (9,
#  ['Region',
#   'Weekend',
#   'VisitorType',
#   'TrafficType',
#   'SpecialDay',
#   'Browser',
#   'OperatingSystems',
#   'Month',
#   'Revenue'])

# %% [markdown]
# ### Target sütunu sayısal değere çeviriyoruz.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
target = data.iloc[:,-1]
target = le.fit_transform(target)
target
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# #Train - Test Split

# %%
x_train,x_test,y_train,y_test=train_test_split(data.drop('Revenue', axis=1), target, test_size = 0.30, random_state=45)

# %% [markdown]
# # Değişkenlerin target (revenue) ile olan ilişkisi

# %%
def plot_feature_distribution(df1, df2, label1, label2, features):
    i = 0
    sns.set_style('whitegrid')
    plt.figure()
    fig, ax = plt.subplots(3,3,figsize=(18,22))

    for feature in features:
        i += 1
        plt.subplot(3,3,i)
        sns.distplot(df1[feature], hist=False,label=label1)
        sns.distplot(df2[feature], hist=False,label=label2)
        plt.xlabel(feature, fontsize=9)### Eksik veriler sadece train
        locs, labels = plt.xticks()
        plt.tick_params(axis='x', which='major', labelsize=6, pad=-6)
        plt.tick_params(axis='y', which='major', labelsize=6)
    plt.show();

# %%
t0 = data.loc[data['Revenue'] == True]
t1 = data.loc[data['Revenue'] == False]
features = data.columns.values[0:9]
plot_feature_distribution(t0, t1, 'True', 'False', features)

# %% [markdown]
# # Target dağılımının histogram olarak gösterimi

# %%
# %matplotlib inline
# Histogram of the target categories
def histogram(df,feature):
    #df = input("Enter a DataFrame name: ")
    #col = input("Enter a target column name: ")
    #df=eval(df)
    ncount = len(df)
    ax = sns.countplot(x = feature, data=df ,palette="hls")
    sns.set(font_scale=1)
    ax.set_xlabel('Target Segments')
    plt.xticks(rotation=90)
    ax.set_ylabel('Number of Observations')
    fig = plt.gcf()
    fig.set_size_inches(12,5)
    # Make twin axis
    ax2=ax.twinx()
    # Switch so count axis is on right, frequency on left
    ax2.yaxis.tick_left()
    ax.yaxis.tick_right()
    # Also switch the labels over
    ax.yaxis.set_label_position('right')
    ax2.yaxis.set_label_position('left')
    ax2.set_ylabel('Frequency [%]')
    for p in ax.patches:
        x=p.get_bbox().get_points()[:,0]
        y=p.get_bbox().get_points()[1,1]
        ax.annotate('{:.2f}%'.format(100.*y/ncount), (x.mean(), y), 
                ha='center', va='bottom') # set the alignment of the text
    # Use a LinearLocator to ensure the correct number of ticks
    
    # Fix the frequency range to 0-100
    ax2.set_ylim(0,100)
    ax.set_ylim(0,ncount)
    # And use a MultipleLocator to ensure a tick spacing of 10
    
    # Need to turn the grid on ax2 off, otherwise the gridlines end up on top of the bars
    ax2.grid(None)
    plt.title('Histogram of Binary Target Categories', fontsize=20, y=1.08)
    plt.show()
    del ncount, x, y

# %%
histogram(data,"Revenue")

# %% [markdown]
# # Korelasyon Haritası

# %%
data[numerical_columns].corr(method = 'spearman')
# Out:
#                          Administrative  ...  PageValues
# Administrative                 1.000000  ...    0.323895
# Informational                  0.366157  ...    0.216437
# Informational_Duration         0.360025  ...    0.221088
# ProductRelated                 0.450223  ...    0.336740
# ProductRelated_Duration        0.410382  ...    0.355479
# BounceRates                   -0.137602  ...   -0.115189
# ExitRates                     -0.422963  ...   -0.302531
# Administrative_Duration        0.938954  ...    0.312767
# PageValues                     0.323895  ...    1.000000
#
# [9 rows x 9 columns]

# %%
data
# Out:
#        Administrative  Administrative_Duration  ...  Weekend  Revenue
# 0                 0.0                      0.0  ...    False    False
# 1                 0.0                      0.0  ...    False    False
# 3                 0.0                      0.0  ...    False    False
# 4                 0.0                      0.0  ...     True    False
# 5                 0.0                      0.0  ...    False    False
# ...               ...                      ...  ...      ...      ...
# 12325             3.0                    145.0  ...     True    False
# 12326             0.0                      0.0  ...     True    False
# 12327             0.0                      0.0  ...     True    False
# 12328             4.0                     75.0  ...    False    False
# 12329             0.0                      0.0  ...     True    False
#
# [12166 rows x 18 columns]

# %% [markdown]
# #### Pearson Korelasyonu aykırı verilere duyarlı olduğundan ve henüz aykırı verileri temizlemediğimizden dolayı "Spearman" korelasyonuna bakma gereği duyuyoruz.

# %%
f,ax = plt.subplots(figsize=(15,15))
sns.heatmap(data[numerical_columns].corr(method = 'spearman'), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %% [markdown]
# # Kategorik Verilerin İncelenmesi

# %%
plt.hist(data.loc[:,"SpecialDay"])
plt.title("SpecialDay")
plt.show()

plt.hist(data.loc[:,"Month"])
plt.title("Month")
plt.show()

plt.hist(data.loc[:,"OperatingSystems"])
plt.title("OperatingSystems")
plt.show()

plt.hist(data.loc[:,"Browser"])
plt.title("Browser")
plt.show()

plt.hist(data.loc[:,"Region"])
plt.title("Region")
plt.show()

plt.hist(data.loc[:,"TrafficType"])
plt.title("TrafficType")
plt.show()

plt.hist(data.loc[:,"VisitorType"])
plt.title("VisitorType")
plt.show()

# %% [markdown]
# # Sayısal Verilerin Yoğunluk Dağılımlı Görselleştirilmesi

# %%
numerical_columns
# Out:
# ['Administrative',
#  'Informational',
#  'Informational_Duration',
#  'ProductRelated',
#  'ProductRelated_Duration',
#  'BounceRates',
#  'ExitRates',
#  'Administrative_Duration',
#  'PageValues']

# %%
#We plotted the numerical features

import matplotlib.pyplot as plt


f,axes=plt.subplots(7,1,figsize=(10,20))
sns.distplot(data[numerical_columns[0]],ax=axes[0])

sns.distplot(data[numerical_columns[1]],ax=axes[1])

sns.distplot(data[numerical_columns[2]],ax=axes[2])

sns.distplot(data[numerical_columns[3]],ax=axes[3])

sns.distplot(data[numerical_columns[4]],ax=axes[4])

sns.distplot(data[numerical_columns[5]],ax=axes[5])

sns.distplot(data[numerical_columns[6]],ax=axes[6])

# %%
sns.pairplot(data[numerical_columns],kind="reg")

# %% [markdown]
# # BI Variate Analysis

# %%
plt.rcParams['figure.figsize'] = (18, 15)

plt.subplot(2, 2, 1)
sns.boxenplot(data['Revenue'], data['Informational_Duration'], palette = 'rainbow')
plt.title('Info. duration vs Revenue', fontsize = 30)
plt.xlabel('Revenue', fontsize = 15)
plt.ylabel('Info. duration', fontsize = 15)

# product related duration vs revenue

plt.subplot(2, 2, 2)
sns.boxenplot(data['Revenue'], data['Administrative_Duration'], palette = 'pastel')
plt.title('Admn. duration vs Revenue', fontsize = 30)
plt.xlabel('Revenue', fontsize = 15)
plt.ylabel('Admn. duration', fontsize = 15)

# product related duration vs revenue

plt.subplot(2, 2, 3)
sns.boxenplot(data['Revenue'], data['ProductRelated_Duration'], palette = 'dark')
plt.title('Product Related duration vs Revenue', fontsize = 30)
plt.xlabel('Revenue', fontsize = 15)
plt.ylabel('Product Related duration', fontsize = 15)

# exit rate vs revenue

plt.subplot(2, 2, 4)
sns.boxenplot(data['Revenue'], data['ExitRates'], palette = 'spring')
plt.title('ExitRates vs Revenue', fontsize = 30)
plt.xlabel('Revenue', fontsize = 15)
plt.ylabel('ExitRates', fontsize = 15)


plt.show()

# %% [markdown]
# # Skeewed Analizi

# %%
df_train = x_train.copy()
numerical_columns_remains = numerical_columns

try:
    with open('left_skewed_columns.csv', 'r') as f:
        left_skewed_columns = list(csv.reader(f))[0][:-1]
except:
    if 'left_skewed_columns' not in globals():
        left_skewed_columns=[]
        for col in numerical_columns_remains:
            if df_train.loc[df_train[col]!=df_train[col].mode()[0],col].median() < -1:
                left_skewed_columns.append(col)

        with open('left_skewed_columns.csv','w') as f:
            for item in left_skewed_columns:
                f.write('%s,'%item)
    else:
        print("'left_skewed_columns' are already identified!")

epsilon=0.001

# Change the direction of skewness of 'left_skewed_columns':
for col in left_skewed_columns:
    if df_train[df_train[col]!=df_train[col].mode()[0]][col].median() < -1:
        df_train.loc[:,col] *= -1
    else:
        continue
        
sparse_columns=[]
for col in numerical_columns_remains:
    if (df_train[col].quantile(0.01)==df_train[col].quantile(0.25)==df_train[col].mode()[0]):
        sparse_columns.append(col)

sparse_columns_2=[]
for col in numerical_columns_remains:
    if (df_train[col].quantile(0.01)==df_train[col].quantile(0.25)):
        sparse_columns_2.append(col)


len(numerical_columns_remains), len(sparse_columns), len(sparse_columns_2)
# Out:
# (9, 6, 6)

# %% [markdown]
# # Outlier Tespiti

# %% [markdown]
# ##Interquailtile yöntemi ile aykırı verileri inceleme

# %%
Q1=data['Administrative_Duration'].quantile(0.25)
Q3=data['Administrative_Duration'].quantile(0.75)
IQR=Q3-Q1
minn=Q1-3*IQR
maxx=Q3+3*IQR
data['Administrative_Duration'][(data['Administrative_Duration']<minn) | (data['Administrative_Duration']> maxx)].count()
# Out:
# 539

# %% [markdown]
# -+ 3 IQR ile işleme tutarak sınırları belirlememize rağmen 548 veri aykırı veri olarak gözükmekte. Bu miktarın tüm veri setindeki gözlem sayısına oranı. %4.5 değerine gelmekte. Bunu fazla bularak dağılımını kontrol etme gereksinimi duyuyoruz

# %%
sns.distplot(data.Administrative_Duration)

# %% [markdown]
# ## Train datasında outlier tespiti

# %%
"""
Algorithm 'HER' applies induction to the elements of a value line which are:

    - lower than the 1th quantile to that quantile and
    - upper than the 99th quantile to that quantile.
    
Main aim is to diminish negative effects of outlier values on analytical operations being performed.
"""

def HardEdgeReduction(df,numerical_columns,sparse_columns,upper_quantile=0.99,lower_quantile=0.01):
    
    import pandas as pd

    import psutil, os, gc, time
    print("HardEdgeReduction process has began:\n")
    proc = psutil.Process(os.getpid())
    gc.collect()
    mem_0 = proc.memory_info().rss
    start_time = time.time()
    
    # Do outlier cleaning in only one loop
    epsilon = 0.0001 # for zero divisions

    # Define boundaries that we will use for Reduction operation

    df_outlier_cleaned = df.copy()

    print("Detected outliers will be replaced with edged quantiles/percentiles: 1% and 99%!\n")
    print("Total number of rows is: %s\n"%df_outlier_cleaned.shape[0])

    outlier_boundries_dict={}

    for col in numerical_columns:

        if col in sparse_columns:

            # First ignore the 'sparse' data points:
            nonsparse_data = pd.DataFrame(df_outlier_cleaned[df_outlier_cleaned[col] !=\
                                                             df_outlier_cleaned[col].mode()[0]][col]) 
            
            #we used only mode to catch sparse points, since we know/proved it is enough to do that.

            # Find Outlier Thresholds:
            # Note: All columns are right-skewed
            # For lower threshold (left-hand-side)
            if nonsparse_data[col].quantile(lower_quantile) < df_outlier_cleaned[col].mode()[0]: #Unexpected case # Bu kısmı çözemezsek soralım
                lower_bound_sparse = nonsparse_data[col].quantile(lower_quantile)
            else:
                lower_bound_sparse = df_outlier_cleaned[col].mode()[0]
            
            # For upper threshold (right-hand-side)
            if nonsparse_data[col].quantile(upper_quantile) < df_outlier_cleaned[col].mode()[0]: #Unexpected case
                upper_bound_sparse = df_outlier_cleaned[col].mode()[0]
            else:
                upper_bound_sparse = nonsparse_data[col].quantile(upper_quantile)

            outlier_boundries_dict[col]=(lower_bound_sparse,upper_bound_sparse)

            # Inform user about the cardinality of Outlier existence:
            number_of_outliers = len(df_outlier_cleaned[(df_outlier_cleaned[col] < lower_bound_sparse) |\
                                                        (df_outlier_cleaned[col] > upper_bound_sparse)][col])
            print("Sparse: Outlier number in %s is equal to: "%col,number_of_outliers/(nonsparse_data.shape[0] -
                                                                                       nonsparse_data.isnull().sum()))

            # Replace Outliers with Edges --> 1% and 99%:
            if number_of_outliers > 0:

                # Replace 'left-hand-side' outliers with its 1% quantile value
                df_outlier_cleaned.loc[df_outlier_cleaned[col] < lower_bound_sparse,col] = lower_bound_sparse - epsilon # --> MAIN DF CHANGED

                # Replace 'right-hand-side' outliers with its 99% quantile value
                df_outlier_cleaned.loc[df_outlier_cleaned[col] > upper_bound_sparse,col] = upper_bound_sparse + epsilon # --> MAIN DF CHANGED

        else:
            # Find Edges:
            number_of_outliers = len(df_outlier_cleaned[(df_outlier_cleaned[col] < \
                                                         df_outlier_cleaned[col].quantile(lower_quantile))|\
                                                        (df_outlier_cleaned[col] > \
                                                         df_outlier_cleaned[col].quantile(upper_quantile))]\
                                     [col])
            print("Other: Outlier number in {} is equal to: ".format(col),number_of_outliers/(df[col].shape[0] -
                                                                                       df[col].isnull().sum())) 

            # Replace 'Standard' outliers:
            if number_of_outliers > 0:
                # Replace all outliers with its %99 quartile
                lower_bound_sparse = df_outlier_cleaned[col].quantile(lower_quantile)
                df_outlier_cleaned.loc[df_outlier_cleaned[col] < \
                                       lower_bound_sparse,col] \
                = lower_bound_sparse  - epsilon

                upper_bound_sparse = df_outlier_cleaned[col].quantile(upper_quantile)
                df_outlier_cleaned.loc[df_outlier_cleaned[col] > \
                                       upper_bound_sparse,col] \
                = upper_bound_sparse  + epsilon

            outlier_boundries_dict[col]=(lower_bound_sparse,upper_bound_sparse)


    print('HardEdgeReduction process has been completed!')
    print("--- in %s minutes ---" % ((time.time() - start_time)/60))

    return df_outlier_cleaned, outlier_boundries_dict

# %%
df_train_outlier_cleaned, outlier_boundries_dict = HardEdgeReduction(x_train, numerical_columns,sparse_columns)
# Out:
# HardEdgeReduction process has began:
#
# Detected outliers will be replaced with edged quantiles/percentiles: 1% and 99%!
#
# Total number of rows is: 8516
#
# Sparse: Outlier number in Administrative is equal to:  Administrative    0.00673
# dtype: float64
# Sparse: Outlier number in Informational is equal to:  Informational    0.008082
# dtype: float64
# Sparse: Outlier number in Informational_Duration is equal to:  Informational_Duration    0.010035
# dtype: float64
# Other: Outlier number in ProductRelated is equal to:  0.012916862376702677
# Other: Outlier number in ProductRelated_Duration is equal to:  0.010098637858149366
# Sparse: Outlier number in BounceRates is equal to:  BounceRates    0.0
# dtype: float64
# Other: Outlier number in ExitRates is equal to:  0.009981211836542978
# Sparse: Outlier number in Administrative_Duration is equal to:  Administrative_Duration    0.010209
# dtype: float64
# Sparse: Outlier number in PageValues is equal to:  PageValues    0.010074
# ...

# %%
outlier_boundries_dict
# Out:
# {'Administrative': (0.0, 16.0),
#  'Administrative_Duration': (0.0, 1144.5126470499972),
#  'BounceRates': (0.0, 0.2),
#  'ExitRates': (0.001282051, 0.2),
#  'Informational': (0.0, 9.0),
#  'Informational_Duration': (0.0, 1476.1424999999992),
#  'PageValues': (0.0, 147.33959212500068),
#  'ProductRelated': (1.0, 221.85000000000036),
#  'ProductRelated_Duration': (0.0, 8758.861504550023)}

# %% [markdown]
# ## Test datasında outlier tespiti

# %%
# Do outlier cleaning in only one loop
epsilon = 0.0001 # for zero divisions

# Define boundaries that we will use for Reduction operation
upper_quantile = 0.99
lower_quantile = 0.01

df_test_outlier_cleaned = x_test.copy()

print("Detected outliers will be replaced with edged quantiles/percentiles: 1% and 99%!\n")
print("Total number of rows is: %s\n"%df_train_outlier_cleaned.shape[0])

for col in numerical_columns_remains:

      lower_bound = outlier_boundries_dict[col][0]
      upper_bound = outlier_boundries_dict[col][1]
        
      # Inform user about the cardinality of Outlier existence:
      number_of_outliers = len(df_test_outlier_cleaned[(df_test_outlier_cleaned[col] < lower_bound) |\
                                                        (df_test_outlier_cleaned[col] > upper_bound)][col])
      print("Sparse: Outlier number in %s is equal to: "%col, number_of_outliers/
            (df_test_outlier_cleaned[col].shape[0] - df_test_outlier_cleaned[col].isnull().sum()))

      # Replace Outliers with Edges --> 1% and 99%:
      if number_of_outliers > 0:

          # Replace 'left-hand-side' outliers with its 1% quantile value
          df_test_outlier_cleaned.loc[df_test_outlier_cleaned[col] < lower_bound,col] = lower_bound  - epsilon # --> MAIN DF CHANGED
          
          # Replace 'right-hand-side' outliers with its 99% quantile value
          df_test_outlier_cleaned.loc[df_test_outlier_cleaned[col] > upper_bound,col] = upper_bound  + epsilon # --> MAIN DF CHANGED
# Out:
# Detected outliers will be replaced with edged quantiles/percentiles: 1% and 99%!
#
# Total number of rows is: 8516
#
# Sparse: Outlier number in Administrative is equal to:  0.005479452054794521
# Sparse: Outlier number in Informational is equal to:  0.0008219178082191781
# Sparse: Outlier number in Informational_Duration is equal to:  0.0013698630136986301
# Sparse: Outlier number in ProductRelated is equal to:  0.012876712328767123
# Sparse: Outlier number in ProductRelated_Duration is equal to:  0.009863013698630137
# Sparse: Outlier number in BounceRates is equal to:  0.0
# Sparse: Outlier number in ExitRates is equal to:  0.011506849315068493
# Sparse: Outlier number in Administrative_Duration is equal to:  0.005753424657534247
# Sparse: Outlier number in PageValues is equal to:  0.002191780821917808

# %%
x_test = df_test_outlier_cleaned
x_train = df_train_outlier_cleaned

# %% [markdown]
# # Kategorik verilerde encoding

# %% [markdown]
# # Train datasında encoding

# %%
x_train1=x_train.copy()
x_test1=x_test.copy()

x_train1=pd.get_dummies(x_train1,columns=["Month"],prefix=["Month"],dummy_na=False)
x_test1=pd.get_dummies(x_test1,columns=["Month"],prefix=["Month"],dummy_na=False,)

binary_encoded_variables = ['TrafficType','Browser', 'OperatingSystems', 'Region', "VisitorType"]


binary_encoder = ce.BinaryEncoder(cols = binary_encoded_variables, drop_invariant=True)
binary_df = binary_encoder.fit_transform(x_train1[binary_encoded_variables])

le = LabelEncoder()
x_train1["Weekend"] = le.fit_transform(x_train1["Weekend"])

x_train1.drop(binary_encoded_variables, axis=1, inplace=True)

frames = [x_train1, binary_df]
x_train1 = pd.concat(frames, axis=1)

# %% [markdown]
# ##Test datasında encoding

# %%
binary_df = binary_encoder.transform(x_test1[binary_encoded_variables])

x_test1["Weekend"] = le.transform(x_test1["Weekend"])

x_test1.drop(binary_encoded_variables, axis=1, inplace=True)

frames=[x_test1, binary_df]
x_test1 = pd.concat(frames, axis=1)

del binary_df

# %% [markdown]
# ## x_train datasının yeni hali

# %%
x_train1
# Out:
#        Administrative  Administrative_Duration  ...  VisitorType_1  VisitorType_2
# 523               1.0                 3.000000  ...              0              1
# 1115              0.0                 0.000000  ...              0              1
# 8112              0.0                 0.000000  ...              0              1
# 6056              0.0                 0.000000  ...              0              1
# 2889              1.0                37.000000  ...              0              1
# ...               ...                      ...  ...            ...            ...
# 175               3.0                87.000000  ...              0              1
# 11969             0.0                 0.000000  ...              0              1
# 6133              7.0                54.842857  ...              0              1
# 6680              3.0                16.000000  ...              0              1
# ...

# %% [markdown]
# <h1>Modellemeler</h1>

# %% [markdown]
# Modellemeler bölümünde; </br>
# 1- ***XGBoost*** modellenmesi-hiperparametre tuning-final modelinin kurulması </br>
# 2- ***Random Forest*** modellenmesi-hiperparametre tuning-final modelinin kurulması </br>
# 3- ***LightGBM*** modellenmesi-hiperparametre tuning-final modelinin kurulması </br>
# 4- ***Logistic Regression*** modellenmesi </br>
# 5- ***Multi Layer Perceptron*** modellenmesi hiperparametre tuning-final modelinin kurulması </br>

# %% [markdown]
# <h2> XGBoost ile modelleme - accuracy score ve ROC score'un gözlemlenmesi </h2>

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, auc, roc_curve

model = XGBClassifier()
model.fit(x_train1, y_train)


y_pred = model.predict(x_test1)
predictions = [round(value) for value in y_pred]

accuracy_score_xbg = accuracy_score(y_test, predictions)
print("Accuracy_Score: %.2f%%" % (accuracy_score_xbg * 100.0))

xg_probs = model.predict_proba(x_test1)
xg_preds = xg_probs[:,1]
fpr, tpr, threshold = roc_curve(y_test, xg_preds)
roc_auc_xgb = auc(fpr, tpr)


lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc_xgb)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Accuracy_Score: 90.08%

# %% [markdown]
# ### XGBoost Feature Importance

# %%
feat_labels=x_train1.columns
importances=[]
df_feat=pd.DataFrame(model.feature_importances_)
df_feat
df_label=pd.DataFrame(feat_labels)
feat_labels
imp_data=pd.concat([df_label,df_feat],axis=1)
imp_data.columns=["0","1"]
imp_data
fig=plt.gcf()

g=sns.catplot(x="0",y="1",kind="bar",data=imp_data)
g.fig.set_figwidth(12)
g.fig.set_figheight(12)
g.set_xticklabels(rotation=90,horizontalalignment="right")

# %% [markdown]
# ### PageValues ve Month sütunlarının taget ile ilişkisi

# %%
a4_dims = (15,10)
fig, ax = plt.subplots(1,2,figsize=a4_dims)

sns.violinplot(x="Revenue", y="PageValues", data=data, ax=ax[0])

sns.violinplot(x="Month", y="Revenue", data=data, ax=ax[1])

# %% [markdown]
# ## XGBoost model hiperparametrelerinin tune edilmesi

# %%
xgb_params= {
    'n_estimators':[100,500,1000,2000],
    'subsample':[0.6,0.8,1.0],
    'max_depth':[3,4,5,6],
    'learning_rate':[0.1,0.01,0.02,0.05],
    'min_samples_split':[2,5,10]
}

# %%
from sklearn.model_selection import GridSearchCV
xgb=XGBClassifier()
xgb_cv_model=GridSearchCV(xgb,
                          xgb_params,
                          cv=5,
                          n_jobs=-1,
                          verbose=2)
#xgb_cv_model.fit(x_train1,y_train)

# %%
#xgb_cv_model.fit(x_train1,y_train)

# %%
#xgb_cv_model.best_params_

# %%
best_params_dict={'learning_rate': 0.01,
 'max_depth': 5,
 'min_samples_split': 2,
 'n_estimators': 500,
 'subsample': 0.6}

# %% [markdown]
# ## XGBoost final modelinin/tune edilmiş modelin kurulması

# %%
xgb_cv_model=XGBClassifier(learning_rate=0.01,
                           max_depth=5,
                           min_samples_split=2,
                           n_estimators=500,
                           subsample=0.6)
xgb_cv_model.fit(x_train1,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.01, max_delta_step=0, max_depth=5,
#               min_child_weight=1, min_samples_split=2, missing=None,
#               n_estimators=500, n_jobs=1, nthread=None,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#               subsample=0.6, verbosity=1)

# %% [markdown]
# ## Final modelin kurulması

# %%
y_cv_pred = xgb_cv_model.predict(x_test1)xg_probs = model.predict_proba(x_test1)

predictions = [round(value) for value in y_cv_pred]

accuracy_score_tuned_xgb = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy_score_tuned_xgb * 100.0))

xg_probs_tuned = xgb_cv_model.predict_proba(x_test1)
xg_preds_tuned = xg_probs_tuned[:,1]
fpr, tpr, threshold = roc_curve(y_test, xg_preds_tuned)
roc_auc_tuned_xgb = auc(fpr, tpr)

lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc_tuned_xgb)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Accuracy: 90.27%

# %% [markdown]
# ## Random Forest modelinin kurulması

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve

model = RandomForestClassifier()
model.fit(x_train1, y_train)

y_pred3 = model.predict(x_test1)

# evaluating the model
print("Training Accuracy :", model.score(x_train1, y_train))
print("Testing Accuracy :", model.score(x_test1, y_test))
accuracy_score_rf=model.score(x_test1, y_test)


# confusion matrix
cm = confusion_matrix(y_test, y_pred3)
plt.rcParams['figure.figsize'] = (6, 6)
sns.heatmap(cm ,annot = True)

# classification report
cr = classification_report(y_test, y_pred3)
print(cr)
# Out:
# Training Accuracy : 1.0
# Testing Accuracy : 0.8994520547945205
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      3075
#            1       0.74      0.56      0.64       575
#
#     accuracy                           0.90      3650
#    macro avg       0.83      0.76      0.79      3650
# weighted avg       0.89      0.90      0.89      3650

# %%
rf_probs = model.predict_proba(x_test1)
rf_pred = rf_probs[:,1]
fpr, tpr, threshold = roc_curve(y_test, rf_pred)
roc_auc_rf = auc(fpr, tpr)



lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc_rf)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Random Forest Classifier'ının tune edilmesi

# %%
from sklearn.model_selection import GridSearchCV
rf_model2=RandomForestClassifier()
rf_params= {"max_depth": [2,5,8,10],
            "max_features": [2,5,8],
            "n_estimators":[10,500,1000],
            "min_samples_split":[2,5,10]}

rf_cv_model=GridSearchCV(rf_model2,
                         rf_params,
                         cv=10,
                         n_jobs=-1,
                         verbose=2)

# %%
# rf_cv_model.fit(x_train1,y_train)

# %%
# rf_cv_model.best_params_

# %%
#rf_tuned=RandomForestClassifier(max_depth=8,
#                                max_features=5,
#                                min_samples_split=5,
#                                n_estimators=500)

# %% [markdown]
# ##Random Forest Classifier final modelinin/tune edilmiş modelinin kurulması

# %%
rf_tuned=RandomForestClassifier(max_depth=10,
                                max_features=8,
                                min_samples_split=5,
                                n_estimators=1000)
rf_tuned.fit(x_train1,y_train)
y_pred4=rf_tuned.predict(x_test1)
accuracy_score_tuned_rf=accuracy_score(y_test,y_pred4)


# evaluating the model
print("Training Accuracy :", rf_tuned.score(x_train1, y_train))
print("Testing Accuracy :", rf_tuned.score(x_test1, y_test))


# confusion matrix
cm = confusion_matrix(y_test, y_pred4)
plt.rcParams['figure.figsize'] = (6, 6)
sns.heatmap(cm ,annot = True)

# classification report
cr = classification_report(y_test, y_pred4)
print(cr)
# Out:
# Training Accuracy : 0.9488022545796149
# Testing Accuracy : 0.9060273972602739
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95      3075
#            1       0.75      0.60      0.67       575
#
#     accuracy                           0.91      3650
#    macro avg       0.84      0.78      0.81      3650
# weighted avg       0.90      0.91      0.90      3650

# %%
rf_probs_tuned = rf_tuned.predict_proba(x_test1)
rf_pred_tuned = rf_probs_tuned[:,1]
fpr, tpr, threshold = roc_curve(y_test, rf_pred_tuned)
roc_auc_tuned_rf = auc(fpr, tpr)



lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc_tuned_rf)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ##LightGBM Classifier modelinin kurulması ve accuracy score'un gözlenmesi

# %%
from lightgbm import LGBMClassifier
lgbm_model=LGBMClassifier()
lgbm_model.fit(x_train1,y_train)

y_pred_lgbm=lgbm_model.predict(x_test1)
accuracy_score_lgbm=accuracy_score(y_test,y_pred_lgbm)
print("Accuracy Score : ",accuracy_score_lgbm)

lgbm_prob = lgbm_model.predict_proba(x_test1)
lgbm_pred = lgbm_prob[:,1]
fpr, tpr, threshold = roc_curve(y_test, lgbm_pred)
roc_auc_lgbm = auc(fpr, tpr)


lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc_lgbm)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Accuracy Score :  0.8972602739726028

# %%
lgbm_params={"n_estimators":[100,500,1000,2000],
             "subsample":[0.6,0.8,1.0],
             "max_depth":[3,4,5,6],
             "learning_rate":[0.1,0.01,0.02,0.05],
             "min_child_samples":[5,10,20]}

# %% [markdown]
# ## LGBM Tune Edilmesi

# %%
lgbm_cv_model=GridSearchCV(lgbm_model,
                           lgbm_params,
                           cv=10,
                           n_jobs=-1,
                           verbose=2)

# %%
#lgbm_cv_model.fit(x_train1,y_train)

# %%
#lgbm_cv_model.best_params_

# %% [markdown]
# ## Tune Edilmiş LGMB Modelinin Kurulması

# %%
lgbm_tuned=LGBMClassifier(learning_rate=0.01,
                          max_depth=4,
                          min_child_samples=10,
                          n_estimators=1000,
                          subsample=0.6)
lgbm_tuned.fit(x_train1,y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.01, max_depth=4,
#                min_child_samples=10, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=1000, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=0.6, subsample_for_bin=200000, subsample_freq=0)

# %%
y_pred_lgbm=lgbm_tuned.predict(x_test1)

accuracy_score_tuned_lgbm=accuracy_score(y_test,y_pred_lgbm)
print("Accuracy_Score: ",accuracy_score_tuned_lgbm)

lgbm_prob_tuned = lgbm_tuned.predict_proba(x_test1)
lgbm_pred_tuned = lgbm_prob_tuned[:,1]
fpr, tpr, threshold = roc_curve(y_test, lgbm_pred_tuned)
roc_auc_tuned_lgbm = auc(fpr, tpr)


lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc_tuned_lgbm)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Accuracy_Score:  0.9002739726027398

# %% [markdown]
# ## Logistic Regression  Modelinin Kurulması

# %%
lr = LogisticRegression()
lr
lr.fit(x_train1,y_train)
lr_score = lr.score(x_test1,y_test)
print("Test Accuracy of LR Algorithm: {:.2f}%".format(lr_score*100))
y_pred5 = lr.predict(x_test1)

lr_prob = lr.predict_proba(x_test1)
lr_pred = lr_prob[:,1]
fpr, tpr, threshold = roc_curve(y_test, lr_pred)
roc_auc = auc(fpr, tpr)


lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Test Accuracy of LR Algorithm: 87.97%

# %% [markdown]
# ## MLP Classifier Modelinin Kurulması

# %%
from sklearn.neural_network import MLPClassifier
mlp_model=MLPClassifier()
mlp_model.fit(x_train1,y_train)
y_mlp_pred=mlp_model.predict(x_test1)

mlp_score=mlp_model.score(x_test1,y_test)
print("MLP Score: {:.2f}%".format(mlp_score*100))

mlp_prob = mlp_model.predict_proba(x_test1)
mlp_pred = mlp_prob[:,1]
fpr, tpr, threshold = roc_curve(y_test, mlp_pred)
roc_auc_mlp = auc(fpr, tpr)


lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc_mlp)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# MLP Score: 87.92%

# %% [markdown]
# ## MLP Classifier Modelinin Tune Edilmesi

# %%
 """mlp_params={"alpha":[0.1,0.01,0.02,0.005,0.0001,0.00001],
             "hidden_layer_sizes":[(30,30,30),(100,100,100),(100,100),
                                   (200,150,140),(250,180,160)],
             "solver":["adam","sgd"],
             "activation":["relu","logistic"]}"""
 mlp_params={"alpha":[0.1,0.01,0.02,0.005,0.0001,0.00001],
             "hidden_layer_sizes":[(40,40,40),(45,45,45),(50,50,50),(50,40,40)],
             "solver":["adam"],
             "activation":["logistic"]}

# %%
#mlp_cv_model=GridSearchCV(mlp_model,mlp_params,cv=10,n_jobs=-1,verbose=2)
#mlp_cv_model.fit(x_train1,y_train)

# %%
#print("En iyi parametreler: "+str(mlp_cv_model.best_params_))

# %% [markdown]
# ## MLP Classifier Final Modelinin/Tune Edilmiş Modelinin Kurulması

# %%
mlp_tuned=MLPClassifier(activation="logistic",alpha=0.02,
                       hidden_layer_sizes=(50,40,40),
                       solver="adam")
mlp_tuned.fit(x_train1,y_train)
y_mlp_tuned=mlp_tuned.predict(x_test1)

mlp_cv_score=mlp_tuned.score(x_test1,y_test)
print("MLP Score: {:.2f}%".format(mlp_cv_score*100))

mlp_prob_tuned = mlp_tuned.predict_proba(x_test1)
mlp_pred_tuned = mlp_prob_tuned[:,1]
fpr, tpr, threshold = roc_curve(y_test, mlp_pred_tuned)
roc_auc_tuned_mlp = auc(fpr, tpr)

lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc_tuned_mlp)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# MLP Score: 88.66%

# %% [markdown]
# # Modellerin Karşılaştırılması

# %%
modelss={"XGB":[round(roc_auc_xgb*100,2),round(roc_auc_tuned_xgb*100,2),round(accuracy_score_xbg*100,2),
                round(accuracy_score_tuned_xgb*100,2)],
         "Random Forest":[round(roc_auc_rf*100,2),round(roc_auc_tuned_rf*100,2),
                          round(accuracy_score_rf*100,2),round(accuracy_score_tuned_rf*100,2)],
         "LGBM":[round(roc_auc_lgbm*100,2),round(roc_auc_tuned_lgbm*100,2),
                 round(accuracy_score_lgbm*100,2),round(accuracy_score_tuned_lgbm*100,2)],
         "MLPClassifier":[round(roc_auc_mlp*100,2),round(roc_auc_tuned_mlp*100,2),
                          round(mlp_score*100,2),round(mlp_cv_score*100,2)],
         "Logistic Regression":[round(roc_auc*100,2),round(roc_auc*100,2),round(lr_score*100,2),round(lr_score*100,2)]}
index=["Roc_Score","Tuned_Roc_Score","Accuracy_Score","Tuned_Accuracy_Score"]
df_modelss=pd.DataFrame(modelss)
df_modelss.index=index
df_modelss
# Out:
#                         XGB  Random Forest  ...  MLPClassifier  Logistic Regression
# Roc_Score             93.02          92.40  ...          84.94                87.63
# Tuned_Roc_Score       93.28          93.16  ...          91.77                87.63
# Accuracy_Score        90.08          89.95  ...          87.92                87.97
# Tuned_Accuracy_Score  90.27          90.60  ...          88.66                87.97
#
# [4 rows x 5 columns]

# %%
aoc_scores_dict={}
N = 5
aoc_scores_dict["LGBM"]=(round(roc_auc_lgbm*100,2),round(roc_auc_tuned_lgbm*100,2))
aoc_scores_dict["RF"]=(round(roc_auc_rf*100,2),round(roc_auc_tuned_rf*100,2))
aoc_scores_dict["LOGR"]=(round(roc_auc*100,2),round(roc_auc*100,2))
aoc_scores_dict["XGB"]=(round(roc_auc_xgb*100,2),round(roc_auc_tuned_xgb*100,2))
aoc_scores_dict["MLPC"]=(round(roc_auc_mlp*100,2),round(roc_auc_tuned_mlp*100,2))

bars1=[aoc_scores_dict["LGBM"][0],aoc_scores_dict["RF"][0],aoc_scores_dict["LOGR"][0],aoc_scores_dict["XGB"][0],aoc_scores_dict["MLPC"][0]]
bars2 =[aoc_scores_dict["LGBM"][1],aoc_scores_dict["RF"][1],aoc_scores_dict["LOGR"][1],aoc_scores_dict["XGB"][1],aoc_scores_dict["MLPC"][1]]

ind = np.arange(N)  # the x locations for the groups
width = 0.35      # the width of the bars


fig, ax = plt.subplots(figsize=(32, 10),dpi=100)
rects1 = ax.bar(ind, bars1, width, color='y')

rects2 = ax.bar(ind + width, bars2, width, color='g')

ax.set_ylabel('Scores')
ax.set_title('ROC AUC/Tuned ROC AUC Score')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('LGBM', 'RF', 'LOGR',"XGB", "MLPC"),fontsize=14)

ax.legend((rects1[0], rects2[0]), ('Model', "Tuned Model"))


def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1*height,
                '%.3f' % height,fontsize=14,
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
